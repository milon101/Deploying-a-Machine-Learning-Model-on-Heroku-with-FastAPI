# %%
# import libraries
import wandb
import pandas as pd
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
run = wandb.init(project="usa_census", group="eda", save_code=True)
local_path = wandb.use_artifact("census.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb version 0.12.21 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/home/imdadul/Project Folder/Deploying a Machine Learning Model on Heroku with FastAPI/src/eda/wandb/run-20220708_093315-2f5944xw</code>
# Syncing run <strong><a href="https://wandb.ai/milon101/usa_census/runs/2f5944xw" target="_blank">earnest-wind-40</a></strong> to <a href="https://wandb.ai/milon101/usa_census" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
cat_features = [
        "workclass",
        "education",
        "marital-status",
        "occupation",
        "relationship",
        "race",
        "sex",
        "native-country"
    ]

for cls in df[cat_features[0]].unique():
            df_temp = df[df[cat_features[0]] == cls]
            print(df_temp)

# %%
cat_features = [
        " workclass",
        "education",
        "marital-status",
        "occupation",
        "relationship",
        "race",
        "sex",
        "native-country"
    ]

for cls in df[cat_features[0]].unique():
            df_temp = df[df[cat_features[0]] == cls]
            print(df_temp)

# %%
cat_features = [
        " workclass",
        "education",
        "marital-status",
        "occupation",
        "relationship",
        "race",
        "sex",
        "native-country"
    ]

df[cat_features[0]].unique()

# for cls in df[cat_features[0]].unique():
#             df_temp = df[df[cat_features[0]] == cls]
#             print(df_temp)
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
# using pandas_profilisng library to get an overall overview of the data
import pandas_profiling
                                                                                                                                                                                                                    
profile = pandas_profiling.ProfileReport(df)
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/29 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
# 5   37            Private   284582     Masters              14
# 6   49            Private   160187         9th               5
# 7   52   Self-emp-not-inc   209642     HS-grad               9
# 8   31            Private    45781     Masters              14
# 9   42            Private   159449   Bachelors              13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# 5      Married-civ-spouse     Exec-managerial            Wife   White
# 6   Married-spouse-absent       Other-service   Not-in-family   Black
# 7      Married-civ-spouse     Exec-managerial         Husband   White
# 8           Never-married      Prof-specialty   Not-in-family   White
# 9      Married-civ-spouse     Exec-managerial         Husband   White
#
#        sex   capital-gain   capital-loss   hours-per-week  native-country  \
# 0     Male           2174              0               40   United-States
# 1     Male              0              0               13   United-States
# 2     Male              0              0               40   United-States
# 3     Male              0              0               40   United-States
# 4   Female              0              0               40            Cuba
# 5   Female              0              0               40   United-States
# 6   Female              0              0               16         Jamaica
# 7     Male              0              0               45   United-States
# 8   Female          14084              0               50   United-States
# 9     Male           5178              0               40   United-States
#
#    salary
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K
# 5   <=50K
# 6   <=50K
# 7    >50K
# 8    >50K
# 9    >50K
#        age      workclass   fnlwgt      education   education-num  \
# 32551   32        Private    34066           10th               6
# 32552   43        Private    84661      Assoc-voc              11
# 32553   32        Private   116138        Masters              14
# 32554   53        Private   321865        Masters              14
# 32555   22        Private   310152   Some-college              10
# 32556   27        Private   257302     Assoc-acdm              12
# 32557   40        Private   154374        HS-grad               9
# 32558   58        Private   151910        HS-grad               9
# 32559   22        Private   201490        HS-grad               9
# 32560   52   Self-emp-inc   287927        HS-grad               9
#
#             marital-status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# 32552   Married-civ-spouse               Sales         Husband
# 32553        Never-married        Tech-support   Not-in-family
# 32554   Married-civ-spouse     Exec-managerial         Husband
# 32555        Never-married     Protective-serv   Not-in-family
# 32556   Married-civ-spouse        Tech-support            Wife
# 32557   Married-civ-spouse   Machine-op-inspct         Husband
# 32558              Widowed        Adm-clerical       Unmarried
# 32559        Never-married        Adm-clerical       Own-child
# 32560   Married-civ-spouse     Exec-managerial            Wife
#
#                       race      sex   capital-gain   capital-loss  \
# 32551   Amer-Indian-Eskimo     Male              0              0
# 32552                White     Male              0              0
# 32553   Asian-Pac-Islander     Male              0              0
# 32554                White     Male              0              0
# 32555                White     Male              0              0
# 32556                White   Female              0              0
# 32557                White     Male              0              0
# 32558                White   Female              0              0
# 32559                White     Male              0              0
# 32560                White   Female          15024              0
#
#         hours-per-week  native-country  salary
# 32551               40   United-States   <=50K
# 32552               45   United-States   <=50K
# 32553               11          Taiwan   <=50K
# 32554               40   United-States    >50K
# 32555               40   United-States   <=50K
# 32556               38   United-States   <=50K
# 32557               40   United-States    >50K
# 32558               40   United-States   <=50K
# 32559               20   United-States   <=50K
# 32560               40   United-States    >50K
#    age  workclass   fnlwgt      education   education-num  marital-status  \
# 8   25    Private   195994        1st-4th               2   Never-married
# 0   19    Private    97261        HS-grad               9   Never-married
# 1   19    Private   138153   Some-college              10   Never-married
# 2   19    Private   146679   Some-college              10   Never-married
# 3   19    Private   251579   Some-college              10   Never-married
# 4   20    Private   107658   Some-college              10   Never-married
# 5   21    Private   243368      Preschool               1   Never-married
# 6   21    Private   250051   Some-college              10   Never-married
# 7   23    Private   240137        5th-6th               3   Never-married
# 9   25    Private   308144      Bachelors              13   Never-married
#
#            occupation    relationship    race      sex   capital-gain  \
# 8     Priv-house-serv   Not-in-family   White   Female              0
# 0     Farming-fishing   Not-in-family   White     Male              0
# 1        Adm-clerical       Own-child   White   Female              0
# 2     Exec-managerial       Own-child   Black     Male              0
# 3       Other-service       Own-child   White     Male              0
# 4        Tech-support   Not-in-family   White   Female              0
# 5     Farming-fishing   Not-in-family   White     Male              0
# 6      Prof-specialty       Own-child   White   Female              0
# 7   Handlers-cleaners   Not-in-family   White     Male              0
# 9        Craft-repair   Not-in-family   White     Male              0
#
#     capital-loss   hours-per-week  native-country  salary  count
# 8              0               40       Guatemala   <=50K      3
# 0              0               40   United-States   <=50K      2
# 1              0               10   United-States   <=50K      2
# 2              0               30   United-States   <=50K      2
# 3              0               14   United-States   <=50K      2
# 4              0               10   United-States   <=50K      2
# 5              0               50          Mexico   <=50K      2
# 6              0               10   United-States   <=50K      2
# 7              0               55          Mexico   <=50K      2
# 9              0               40          Mexico   <=50K      2
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
cat_features = [
        " workclass",
        "education",
        "marital-status",
        "occupation",
        "relationship",
        "race",
        "sex",
        "native-country"
    ]

df[cat_features[0]].unique()

for cls in df[cat_features[0]].unique():
            df_temp = df[df[cat_features[0]] == cls]
            print(df_temp)

# %%
cat_features = [
        " workclass",
        "education",
        "marital-status",
        "occupation",
        "relationship",
        "race",
        "sex",
        "native-country"
    ]

df[cat_features[0]].unique()

for cls in df[cat_features[0]].unique():
            df_temp = df[df[cat_features[0]] == cls]
            print(df_temp.head())

# %%
# import libraries
import wandb
import pandas as pd
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         
run = wandb.init(project="usa_census", group="eda", save_code=True)
local_path = wandb.use_artifact("census.csv:latest").file()
df = pd.read_csv(local_path)
